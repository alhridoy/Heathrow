# %%
# load libraries
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import geopandas as gpd

import pandas as pd
import numpy as np

from matplotlib import pyplot as plt
from matplotlib.dates import date2num, num2date
from matplotlib import dates as mdates
from matplotlib import ticker
from matplotlib.colors import ListedColormap
from matplotlib.patches import Patch
from scipy import stats as sps
from scipy.interpolate import interp1d

from IPython.display import clear_output


# %config InlineBackend.figure_format = 'retina'



plt.rcParams['figure.figsize']=[12,8]

# %%
# set the filepath and load in a shapefile
fp = "iho.shp"

map_df = gpd.read_file(fp)

# %%
map_df
# Out:
#       name  id  longitude   latitude      min_x      min_y      max_x  \
# 0  Red Sea  37  38.735042  20.315731  33.639371  12.456262  43.505521
#
#        max_y      area  mrgid  \
# 0  28.139543  449811.0   4264
#
#                                             geometry
# 0  POLYGON ((34.71160 28.13827, 34.71577 28.12500...

# %%
# 46.76590741
# 47.08717073
# 49.63553571
# 51.11529412
# 54.2182381
# 56.60719048
# 54.86325
# 52.70118919
# 51.84091892
# 48.48461538
# 48.94823404
# 47.78255263

# %%
map_df["nox_1"]=46.76590741
map_df["nox_2"]=47.08717073
map_df["nox_3"]=49.63553571
map_df["nox_4"]=51.11529412

map_df["nox_5"]=54.2182381
map_df["nox_6"]=56.60719048
map_df["nox_7"]=54.86325
map_df["nox_8"]=52.70118919

map_df["nox_9"]=51.84091892
map_df["nox_10"]=48.48461538
map_df["nox_11"]=48.94823404
map_df["nox_12"]=47.78255263

# %%
map_df
# Out:
#       name  id  longitude   latitude      min_x      min_y      max_x  \
# 0  Red Sea  37  38.735042  20.315731  33.639371  12.456262  43.505521
#
#        max_y      area  mrgid  ...      nox_3      nox_4      nox_5     nox_6  \
# 0  28.139543  449811.0   4264  ...  49.635536  51.115294  54.218238  56.60719
#
#       nox_7      nox_8      nox_9     nox_10     nox_11     nox_12
# 0  54.86325  52.701189  51.840919  48.484615  48.948234  47.782553
#
# [1 rows x 23 columns]

# %%
map_df.plot()

# %%
#### # set a variable that will call whatever column we want to visualise on the map
variable = 'nox_1'

# set the range for the choropleth
vmin, vmax = 46, 47

# create figure and axes for Matplotlib
fig, ax = plt.subplots(1, figsize=(10, 6))

# create map
map_df.plot(column=variable, cmap='OrRd', linewidth=0.8, ax=ax, edgecolor='0.8',legend=True)

# Now we can customise and add annotations

# ax.text(x=34-0.15, y=13, s='N', fontsize=20)
# ax.arrow(34.215, 13, 0, 0.16, length_includes_head=True,
#           head_width=0.08, head_length=0.3, overhang=.3, facecolor='k')

# remove the axis
# ax.axis('off')

# add a title
ax.set_title('January', \
              fontdict={'fontsize': '12',
                        'fontweight' : '2'})

# create an annotation for the  data source
# ax.annotate('Source: TROPOMI Sentinel 5p',
#            xy=(0.1, .08), xycoords='figure fraction',
#            horizontalalignment='left', verticalalignment='top',
#            fontsize=10, color='#555555')



# plt.xlim(88.8, 90.4)
# plt.ylim(21.5, 23.5)

# Create colorbar as a legend
# sm = plt.cm.ScalarMappable(cmap='OrRd', norm=plt.Normalize(vmin=vmin, vmax=vmax))
# sm = plt.cm.ScalarMappable(cmap='OrRd')
# sm._A = []
# cbar = fig.colorbar(sm)

# this will save the figure as a high-res png. you can also save as svg
# fig.savefig('testmap.png', dpi=300)

plt.show()

# %%
#### # set a variable that will call whatever column we want to visualise on the map
variable = 'nox_2'

# set the range for the choropleth
vmin, vmax = 47, 48

# create figure and axes for Matplotlib
fig, ax = plt.subplots(1, figsize=(10, 6))

# create map
map_df.plot(column=variable, cmap='OrRd', linewidth=0.8, ax=ax, edgecolor='0.8',legend=True)

# Now we can customise and add annotations

# ax.text(x=34-0.15, y=13, s='N', fontsize=20)
# ax.arrow(34.215, 13, 0, 0.16, length_includes_head=True,
#           head_width=0.08, head_length=0.3, overhang=.3, facecolor='k')

# remove the axis
# ax.axis('off')

# add a title
ax.set_title('February', \
              fontdict={'fontsize': '12',
                        'fontweight' : '2'})

# create an annotation for the  data source
# ax.annotate('Source: TROPOMI Sentinel 5p',
#            xy=(0.1, .08), xycoords='figure fraction',
#            horizontalalignment='left', verticalalignment='top',
#            fontsize=10, color='#555555')



# plt.xlim(88.8, 90.4)
# plt.ylim(21.5, 23.5)

# Create colorbar as a legend
# sm = plt.cm.ScalarMappable(cmap='OrRd', norm=plt.Normalize(vmin=vmin, vmax=vmax))
# sm = plt.cm.ScalarMappable(cmap='OrRd')
# sm._A = []
# cbar = fig.colorbar(sm)

# this will save the figure as a high-res png. you can also save as svg
# fig.savefig('testmap.png', dpi=300)

plt.show()

# %%
#### # set a variable that will call whatever column we want to visualise on the map
variable = 'nox_3'

# set the range for the choropleth
vmin, vmax = 1, 200

# create figure and axes for Matplotlib
fig, ax = plt.subplots(1, figsize=(10, 6))

# create map
map_df.plot(column=variable, cmap='OrRd', linewidth=0.8, ax=ax, edgecolor='0.8',legend=True)

# Now we can customise and add annotations

# ax.text(x=34-0.15, y=13, s='N', fontsize=20)
# ax.arrow(34.215, 13, 0, 0.16, length_includes_head=True,
#           head_width=0.08, head_length=0.3, overhang=.3, facecolor='k')

# remove the axis
# ax.axis('off')

# add a title
ax.set_title('March', \
              fontdict={'fontsize': '12',
                        'fontweight' : '2'})

# create an annotation for the  data source
# ax.annotate('Source: TROPOMI Sentinel 5p',
#            xy=(0.1, .08), xycoords='figure fraction',
#            horizontalalignment='left', verticalalignment='top',
#            fontsize=10, color='#555555')



# plt.xlim(88.8, 90.4)
# plt.ylim(21.5, 23.5)

# Create colorbar as a legend
# sm = plt.cm.ScalarMappable(cmap='OrRd', norm=plt.Normalize(vmin=vmin, vmax=vmax))
# sm = plt.cm.ScalarMappable(cmap='OrRd')
# sm._A = []
# cbar = fig.colorbar(sm)

# this will save the figure as a high-res png. you can also save as svg
# fig.savefig('testmap.png', dpi=300)

plt.show()

# %%
#### # set a variable that will call whatever column we want to visualise on the map
variable = 'nox_4'

# set the range for the choropleth
vmin, vmax = 47, 48

# create figure and axes for Matplotlib
fig, ax = plt.subplots(1, figsize=(10, 6))

# create map
map_df.plot(column=variable, cmap='OrRd', linewidth=0.8, ax=ax, edgecolor='0.8',legend=True)

# Now we can customise and add annotations

# ax.text(x=34-0.15, y=13, s='N', fontsize=20)
# ax.arrow(34.215, 13, 0, 0.16, length_includes_head=True,
#           head_width=0.08, head_length=0.3, overhang=.3, facecolor='k')

# remove the axis
# ax.axis('off')

# add a title
ax.set_title('April', \
              fontdict={'fontsize': '12',
                        'fontweight' : '2'})

# create an annotation for the  data source
# ax.annotate('Source: TROPOMI Sentinel 5p',
#            xy=(0.1, .08), xycoords='figure fraction',
#            horizontalalignment='left', verticalalignment='top',
#            fontsize=10, color='#555555')



# plt.xlim(88.8, 90.4)
# plt.ylim(21.5, 23.5)

# Create colorbar as a legend
# sm = plt.cm.ScalarMappable(cmap='OrRd', norm=plt.Normalize(vmin=vmin, vmax=vmax))
# sm = plt.cm.ScalarMappable(cmap='OrRd')
# sm._A = []
# cbar = fig.colorbar(sm)

# this will save the figure as a high-res png. you can also save as svg
# fig.savefig('testmap.png', dpi=300)

plt.show()

# %%
#### # set a variable that will call whatever column we want to visualise on the map
variable = 'nox_5'

# set the range for the choropleth
vmin, vmax = 50, 300

# create figure and axes for Matplotlib
fig, ax = plt.subplots(1, figsize=(10, 6))

# create map
map_df.plot(column=variable, cmap='OrRd', linewidth=0.8, ax=ax, edgecolor='0.8',legend=True)

# Now we can customise and add annotations

# ax.text(x=34-0.15, y=13, s='N', fontsize=20)
# ax.arrow(34.215, 13, 0, 0.16, length_includes_head=True,
#           head_width=0.08, head_length=0.3, overhang=.3, facecolor='k')

# remove the axis
# ax.axis('off')

# add a title
ax.set_title('May', \
              fontdict={'fontsize': '12',
                        'fontweight' : '2'})

# create an annotation for the  data source
# ax.annotate('Source: TROPOMI Sentinel 5p',
#            xy=(0.1, .08), xycoords='figure fraction',
#            horizontalalignment='left', verticalalignment='top',
#            fontsize=10, color='#555555')



# plt.xlim(88.8, 90.4)
# plt.ylim(21.5, 23.5)

# Create colorbar as a legend
# sm = plt.cm.ScalarMappable(cmap='OrRd', norm=plt.Normalize(vmin=vmin, vmax=vmax))
# sm = plt.cm.ScalarMappable(cmap='OrRd')
# sm._A = []
# cbar = fig.colorbar(sm)

# this will save the figure as a high-res png. you can also save as svg
# fig.savefig('testmap.png', dpi=300)

plt.show()

# %%
#### # set a variable that will call whatever column we want to visualise on the map
variable = 'nox_6'

# set the range for the choropleth
vmin, vmax = 50, 300

# create figure and axes for Matplotlib
fig, ax = plt.subplots(1, figsize=(10, 6))

# create map
map_df.plot(column=variable, cmap='OrRd', linewidth=0.8, ax=ax, edgecolor='0.8',legend=True)

# Now we can customise and add annotations

# ax.text(x=34-0.15, y=13, s='N', fontsize=20)
# ax.arrow(34.215, 13, 0, 0.16, length_includes_head=True,
#           head_width=0.08, head_length=0.3, overhang=.3, facecolor='k')

# remove the axis
# ax.axis('off')

# add a title
ax.set_title('June', \
              fontdict={'fontsize': '12',
                        'fontweight' : '2'})

# create an annotation for the  data source
# ax.annotate('Source: TROPOMI Sentinel 5p',
#            xy=(0.1, .08), xycoords='figure fraction',
#            horizontalalignment='left', verticalalignment='top',
#            fontsize=10, color='#555555')



# plt.xlim(88.8, 90.4)
# plt.ylim(21.5, 23.5)

# Create colorbar as a legend
# sm = plt.cm.ScalarMappable(cmap='OrRd', norm=plt.Normalize(vmin=vmin, vmax=vmax))
# sm = plt.cm.ScalarMappable(cmap='OrRd')
# sm._A = []
# cbar = fig.colorbar(sm)

# this will save the figure as a high-res png. you can also save as svg
# fig.savefig('testmap.png', dpi=300)

plt.show()

# %%
#### # set a variable that will call whatever column we want to visualise on the map
variable = 'nox_7'

# set the range for the choropleth
vmin, vmax = 50, 54

# create figure and axes for Matplotlib
fig, ax = plt.subplots(1, figsize=(10, 6))

# create map
map_df.plot(column=variable, cmap='OrRd', linewidth=0.8, ax=ax, edgecolor='0.8',legend=True)

# Now we can customise and add annotations

# ax.text(x=34-0.15, y=13, s='N', fontsize=20)
# ax.arrow(34.215, 13, 0, 0.16, length_includes_head=True,
#           head_width=0.08, head_length=0.3, overhang=.3, facecolor='k')

# remove the axis
# ax.axis('off')

# add a title
ax.set_title('July', \
              fontdict={'fontsize': '12',
                        'fontweight' : '2'})

# create an annotation for the  data source
# ax.annotate('Source: TROPOMI Sentinel 5p',
#            xy=(0.1, .08), xycoords='figure fraction',
#            horizontalalignment='left', verticalalignment='top',
#            fontsize=10, color='#555555')



# plt.xlim(88.8, 90.4)
# plt.ylim(21.5, 23.5)

# Create colorbar as a legend
# sm = plt.cm.ScalarMappable(cmap='OrRd', norm=plt.Normalize(vmin=vmin, vmax=vmax))
# sm = plt.cm.ScalarMappable(cmap='OrRd')
# sm._A = []
# cbar = fig.colorbar(sm)

# this will save the figure as a high-res png. you can also save as svg
# fig.savefig('testmap.png', dpi=300)

plt.show()

# %%
#### # set a variable that will call whatever column we want to visualise on the map
variable = 'nox_8'

# set the range for the choropleth
vmin, vmax = 50, 54

# create figure and axes for Matplotlib
fig, ax = plt.subplots(1, figsize=(10, 6))

# create map
map_df.plot(column=variable, cmap='OrRd', linewidth=0.8, ax=ax, edgecolor='0.8',legend=True)

# Now we can customise and add annotations

# ax.text(x=34-0.15, y=13, s='N', fontsize=20)
# ax.arrow(34.215, 13, 0, 0.16, length_includes_head=True,
#           head_width=0.08, head_length=0.3, overhang=.3, facecolor='k')

# remove the axis
# ax.axis('off')

# add a title
ax.set_title('August', \
              fontdict={'fontsize': '12',
                        'fontweight' : '2'})

# create an annotation for the  data source
# ax.annotate('Source: TROPOMI Sentinel 5p',
#            xy=(0.1, .08), xycoords='figure fraction',
#            horizontalalignment='left', verticalalignment='top',
#            fontsize=10, color='#555555')



# plt.xlim(88.8, 90.4)
# plt.ylim(21.5, 23.5)

# Create colorbar as a legend
# sm = plt.cm.ScalarMappable(cmap='OrRd', norm=plt.Normalize(vmin=vmin, vmax=vmax))
# sm = plt.cm.ScalarMappable(cmap='OrRd')
# sm._A = []
# cbar = fig.colorbar(sm)

# this will save the figure as a high-res png. you can also save as svg
# fig.savefig('testmap.png', dpi=300)

plt.show()

# %%
#### # set a variable that will call whatever column we want to visualise on the map
variable = 'nox_9'

# set the range for the choropleth
vmin, vmax = 50, 100

# create figure and axes for Matplotlib
fig, ax = plt.subplots(1, figsize=(10, 6))

# create map
map_df.plot(column=variable, cmap='OrRd', linewidth=0.8, ax=ax, edgecolor='0.8',legend=True)

# Now we can customise and add annotations

# ax.text(x=34-0.15, y=13, s='N', fontsize=20)
# ax.arrow(34.215, 13, 0, 0.16, length_includes_head=True,
#           head_width=0.08, head_length=0.3, overhang=.3, facecolor='k')

# remove the axis
# ax.axis('off')

# add a title
ax.set_title('September', \
              fontdict={'fontsize': '12',
                        'fontweight' : '2'})

# create an annotation for the  data source
# ax.annotate('Source: TROPOMI Sentinel 5p',
#            xy=(0.1, .08), xycoords='figure fraction',
#            horizontalalignment='left', verticalalignment='top',
#            fontsize=10, color='#555555')



# plt.xlim(88.8, 90.4)
# plt.ylim(21.5, 23.5)

# Create colorbar as a legend
# sm = plt.cm.ScalarMappable(cmap='OrRd', norm=plt.Normalize(vmin=vmin, vmax=vmax))
# sm = plt.cm.ScalarMappable(cmap='OrRd')
# sm._A = []
# cbar = fig.colorbar(sm)

# this will save the figure as a high-res png. you can also save as svg
# fig.savefig('testmap.png', dpi=300)

plt.show()

# %%
#### # set a variable that will call whatever column we want to visualise on the map
variable = 'nox_10'

# set the range for the choropleth
vmin, vmax = 50, 100

# create figure and axes for Matplotlib
fig, ax = plt.subplots(1, figsize=(10, 6))

# create map
map_df.plot(column=variable, cmap='OrRd', linewidth=0.8, ax=ax, edgecolor='0.8',legend=True)

# Now we can customise and add annotations

# ax.text(x=34-0.15, y=13, s='N', fontsize=20)
# ax.arrow(34.215, 13, 0, 0.16, length_includes_head=True,
#           head_width=0.08, head_length=0.3, overhang=.3, facecolor='k')

# remove the axis
# ax.axis('off')

# add a title
ax.set_title('October', \
              fontdict={'fontsize': '12',
                        'fontweight' : '2'})

# create an annotation for the  data source
# ax.annotate('Source: TROPOMI Sentinel 5p',
#            xy=(0.1, .08), xycoords='figure fraction',
#            horizontalalignment='left', verticalalignment='top',
#            fontsize=10, color='#555555')



# plt.xlim(88.8, 90.4)
# plt.ylim(21.5, 23.5)

# Create colorbar as a legend
# sm = plt.cm.ScalarMappable(cmap='OrRd', norm=plt.Normalize(vmin=vmin, vmax=vmax))
# sm = plt.cm.ScalarMappable(cmap='OrRd')
# sm._A = []
# cbar = fig.colorbar(sm)

# this will save the figure as a high-res png. you can also save as svg
# fig.savefig('testmap.png', dpi=300)

plt.show()

# %%
#### # set a variable that will call whatever column we want to visualise on the map
variable = 'nox_11'

# set the range for the choropleth
vmin, vmax = 50, 100

# create figure and axes for Matplotlib
fig, ax = plt.subplots(1, figsize=(10, 6))

# create map
map_df.plot(column=variable, cmap='OrRd', linewidth=0.8, ax=ax, edgecolor='0.8',legend=True)

# Now we can customise and add annotations

# ax.text(x=34-0.15, y=13, s='N', fontsize=20)
# ax.arrow(34.215, 13, 0, 0.16, length_includes_head=True,
#           head_width=0.08, head_length=0.3, overhang=.3, facecolor='k')

# remove the axis
# ax.axis('off')

# add a title
ax.set_title('November', \
              fontdict={'fontsize': '12',
                        'fontweight' : '2'})

# create an annotation for the  data source
# ax.annotate('Source: TROPOMI Sentinel 5p',
#            xy=(0.1, .08), xycoords='figure fraction',
#            horizontalalignment='left', verticalalignment='top',
#            fontsize=10, color='#555555')



# plt.xlim(88.8, 90.4)
# plt.ylim(21.5, 23.5)

# Create colorbar as a legend
# sm = plt.cm.ScalarMappable(cmap='OrRd', norm=plt.Normalize(vmin=vmin, vmax=vmax))
# sm = plt.cm.ScalarMappable(cmap='OrRd')
# sm._A = []
# cbar = fig.colorbar(sm)

# this will save the figure as a high-res png. you can also save as svg
# fig.savefig('testmap.png', dpi=300)

plt.show()

# %%
#### # set a variable that will call whatever column we want to visualise on the map
variable = 'nox_12'

# set the range for the choropleth
vmin, vmax = 50, 100

# create figure and axes for Matplotlib
fig, ax = plt.subplots(1, figsize=(10, 6))

# create map
map_df.plot(column=variable, cmap='OrRd', linewidth=0.8, ax=ax, edgecolor='0.8',legend=True)

# Now we can customise and add annotations

# ax.text(x=34-0.15, y=13, s='N', fontsize=20)
# ax.arrow(34.215, 13, 0, 0.16, length_includes_head=True,
#           head_width=0.08, head_length=0.3, overhang=.3, facecolor='k')

# remove the axis
# ax.axis('off')

# add a title
ax.set_title('December', \
              fontdict={'fontsize': '12',
                        'fontweight' : '2'})

# create an annotation for the  data source
# ax.annotate('Source: TROPOMI Sentinel 5p',
#            xy=(0.1, .08), xycoords='figure fraction',
#            horizontalalignment='left', verticalalignment='top',
#            fontsize=10, color='#555555')



# plt.xlim(88.8, 90.4)
# plt.ylim(21.5, 23.5)

# Create colorbar as a legend
# sm = plt.cm.ScalarMappable(cmap='OrRd', norm=plt.Normalize(vmin=vmin, vmax=vmax))
# sm = plt.cm.ScalarMappable(cmap='OrRd')
# sm._A = []
# cbar = fig.colorbar(sm)

# this will save the figure as a high-res png. you can also save as svg
# fig.savefig('testmap.png', dpi=300)

plt.show()
